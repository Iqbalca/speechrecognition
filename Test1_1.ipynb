# %% [markdown]
# <a href="https://colab.research.google.com/github/Iqbalca/speechrecognition/blob/main/Test1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install huggingsound

# %%
from huggingsound import SpeechRecognitionModel

# %%
model = SpeechRecognitionModel("jonatasgrosman/wav2vec2-large-xlsr-53-german")
# Out:
# 07/05/2022 08:19:01 - INFO - huggingsound.speech_recognition.model - Loading model...
# Downloading:   0%|          | 0.00/1.74k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.18G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/262 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/85.0 [00:00<?, ?B/s]

# %%
references = [
    {"path": "AG_dialect.wav", "transcription": "Ich möchte noch darauf hinweisen, dass es Unterschiede in der Aussprache oder unterschiedliche Wörter innerhalb ein- und derselben Dialektgruppe gibt, zum Beispiel klingt eine Person aus Tirol in der Aussprache ganz anders als jemand aus der Steiermark, obwohl beide Bundesländer zur südbayerischen Dialektgruppe gehören des. Des weiteren gibt es Unterschiede innerhalb ein- und desselben Bundeslandes die Aussprache"},
    {"path": "AG_sample1.mp3", "transcription": "Hallo drüfen wir mal euch kurz wine Frage stellen und zwar, wenn ihr Wien in einem  wort beschreiben müsstet was wär denn das hmm ist ne gute frage ääh belebt und zwar wenn du wien in wien in einem wort beschreiben müsstest was wär das für win wort hostorisch Anders Anders anders ja anders Schönes wien ne Schönes wien sie selber aus wien ja ich bin win wiener win echter  wiener win echter wiener win ottakringer hallo hast du ganz kurz zeit sorry in English in English yeah one word for vienna if vienna in one word do you have a word for us wow one word for vienna intense wir suchen wienerische worte order was echt wienerisches  Ja schaumrollen schaumrollen zum beispiel schaumrollen schaumrollen ja das ist das stimmt"},
]

evaluation = model.evaluate(references)
# Out:
# 100%|██████████| 2/2 [01:50<00:00, 55.37s/it]

# %%
print(evaluation)
# Out:
# {'cer': 0.3209764918625678, 'wer': 0.6951871657754011}
