# %% [markdown]
# <a href="https://colab.research.google.com/github/Iqbalca/speechrecognition/blob/main/Test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Fine-tuned XLSR-53 large model for speech recognition in German**
#
# This model is used directly by HuggingSound: A toolkit for speech-related tasks based on HuggingFace's tools.
#
# It is just an easy-to-use toolkit for speech-related experiments.

# %%
# !pip install huggingsound

# %%
from huggingsound import SpeechRecognitionModel

# %%
model = SpeechRecognitionModel("jonatasgrosman/wav2vec2-large-xlsr-53-german")
# Out:
# 07/05/2022 07:07:47 - INFO - huggingsound.speech_recognition.model - Loading model...
# Downloading:   0%|          | 0.00/1.74k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.18G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/262 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/85.0 [00:00<?, ?B/s]

# %%
audio_paths = ["AG_dialect.wav", "AG_sample1.mp3"]

# %%
transcriptions = model.transcribe(audio_paths)
# Out:
# 100%|██████████| 2/2 [01:38<00:00, 49.28s/it]

# %%
print(transcriptions)
# Out:
# [{'transcription': 'ich möchte noch darauf hinweisen dass es unterschiede in der aussprache oder unterschiedliche wörter innerhalb ein- und derselben dialektgruppe gibt zum beispiel klingt eine person aus tirol in der aussprache ganz anders als jemand aus der steiermark obwohl beide bundesländer zur südbayerischen dialektgruppe gehörendes weiteren gibt es unterschiede innerhalb ein- und desselben bundeslandes die aussprache', 'start_timestamps': [1940, 1960, 2000, 2040, 2080, 2120, 2180, 2220, 2260, 2300, 2360, 2400, 2440, 2460, 2500, 2540, 2580, 2600, 2680, 2720, 2760, 2820, 2860, 2920, 2960, 3020, 3100, 3180, 3220, 3340, 3380, 3420, 3480, 3560, 3580, 3620, 3680, 3720, 3760, 3800, 3860, 3940, 4000, 4060, 4100, 4140, 4200, 4240, 4260, 4320, 4360, 4420, 4460, 4520, 4560, 4600, 4620, 4660, 4680, 4720, 4740, 4820, 4840, 4920, 5000, 5060, 5120, 5180, 5300, 5340, 5420, 5500, 5600, 5680, 5720, 5740, 5780, 5880, 5920, 5980, 6020, 6060, 6100, 6140, 6180, 6220, 6240, 6280, 6340, 6360, 6400, 6
# ...

# %% [markdown]
# # transcriptions format (a list of dicts, one for each audio file):
# # [
# #  {
# #   "transcription": "extraordinary claims require extraordinary evidence",
# #   "start_timestamps": [100, 120, 140, 180, ...],
# #   "end_timestamps": [120, 140, 180, 200, ...],
# #   "probabilities": [0.95, 0.88, 0.9, 0.97, ...]
# # },
# # ...]
# #
# # as you can see, not only the transcription is returned but also the timestamps (in milliseconds)
# # and probabilities of each character of the transcription
